# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras
from tensorflow.keras.preprocessing import image

# %%
img=image.load_img('IMG/1/1.jpg')

# %%
plt.imshow(img)

# %%
import cv2 as cv
